# %% [markdown]
# # 서울시 자치구별 CCTV 현황 데이터 분석

# %% [markdown]
# # 1. 서울시 자치구별 CCTV 현황 데이터 읽어오기

# %%
import pandas as pd

# excel 로 저장된 csv 화일 읽어오기 
#한글에 오류가 있는 경우 
#encoding='cp949’(MS office에서 저장한 파일 형식)  또는 encoding='utf-8’(그 외 일반적인 경우)

CCTV_Seoul = pd.read_csv('서울시 CCTV 설치운영 현황(자치구)-연도별.csv',encoding='cp949')

# %%
#전체 데이터 보기
CCTV_Seoul
# Out:
#       구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0      계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1    종로구   1729       216      7     10    582    210    150      1    259
# 2     중구   2001        16      6    199     90    125    218    333    462
# 3    용산구   2383        31      3     71    234    125    221    298    351
# 4    성동구   3515       487     26    122    207    112    335    309    790
# 5    광진구   2556        11     24     57    100    187     98     52    675
# 6   동대문구   2315       960    130    146     60     29    111    233    136
# 7    중랑구   3285       298     21     23    253     88    138    159    152
# 8    성북구   3754        42     41     87    174    230    323    587    461
# 9    강북구   2462         0      0      0     55     85    130    311     34
# 10   도봉구   1356         0     49     29     96    181     79    159    134
# ...

# %% [markdown]
# # 2. CCTV 현황 데이터 살펴보기

# %%
#데이터의 위에서 5행 보기
CCTV_Seoul.head()
# Out:
#     구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#0~10번째 데이터행 보기
CCTV_Seoul[0:11]
# Out:
#       구분     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0      계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1    종로구   1729       216      7     10    582    210    150      1    259
# 2     중구   2001        16      6    199     90    125    218    333    462
# 3    용산구   2383        31      3     71    234    125    221    298    351
# 4    성동구   3515       487     26    122    207    112    335    309    790
# 5    광진구   2556        11     24     57    100    187     98     52    675
# 6   동대문구   2315       960    130    146     60     29    111    233    136
# 7    중랑구   3285       298     21     23    253     88    138    159    152
# 8    성북구   3754        42     41     87    174    230    323    587    461
# 9    강북구   2462         0      0      0     55     85    130    311     34
# 10   도봉구   1356         0     49     29     96    181     79    159    134
#
#     2018년  2019년  2020년
# 0    9687  11657  10232
# ...

# %%
#데이터의 아래에서 5행 보기
CCTV_Seoul.tail()
# Out:
#      구분    총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 21  관악구  4909       320    120     84    431    441    608    620    684
# 22  서초구  3730         0    117     72     93     71    563    516   1061
# 23  강남구  6645        62     61     72    368    455    845   1307   1004
# 24  송파구  2743        64      9     61     86     85    215    146    241
# 25  강동구  2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %%
# 20번째부터 마지막까지 데이터 행 보기
CCTV_Seoul[20:]
# Out:
#      구분    총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 20  동작구  2262       165     73     93     29    503    130    254    278
# 21  관악구  4909       320    120     84    431    441    608    620    684
# 22  서초구  3730         0    117     72     93     71    563    516   1061
# 23  강남구  6645        62     61     72    368    455    845   1307   1004
# 24  송파구  2743        64      9     61     86     85    215    146    241
# 25  강동구  2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 20    255    242    240
# 21    674    596    331
# 22    436    361    440
# 23    744    796    931
# 24    542   1068    226
# 25    377    356    614

# %%
#15~25번째 데이터행 보기
CCTV_Seoul[15:26]
# Out:
#       구분    총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 15   양천구  3307      1217    282    175    201    173    193    351    120
# 16   강서구  2437        26     29    129    106    213    188    168    506
# 17   구로구  4075       643    209    216    349    187    268    326    540
# 18   금천구  2365         0      0      0    178     80    361    133    196
# 19  영등포구  3773       450    122    136    238    123    209    248    311
# 20   동작구  2262       165     73     93     29    503    130    254    278
# 21   관악구  4909       320    120     84    431    441    608    620    684
# 22   서초구  3730         0    117     72     93     71    563    516   1061
# 23   강남구  6645        62     61     72    368    455    845   1307   1004
# 24   송파구  2743        64      9     61     86     85    215    146    241
# 25   강동구  2547       223     45     27    227     49    154    202    273
#
#     2018년  2019년  2020년
# 15    142    255    198
# 16    259    457    356
# ...

# %%
#2011년 열의 데이터 보기
CCTV_Seoul['2011년']
# Out:
# 0     1619
# 1        7
# 2        6
# 3        3
# 4       26
# 5       24
# 6      130
# 7       21
# 8       41
# 9        0
# 10      49
# 11       0
# 12       0
# 13     179
# 14      66
# 15     282
# 16      29
# 17     209
# 18       0
# 19     122
# 20      73
# 21     120
# 22     117
# 23      61
# 24       9
# 25      45
# Name: 2011년, dtype: int64

# %%
#2011년과 2020년 열의 데이터 보기
CCTV_Seoul[['2011년','2020년']]
# Out:
#     2011년  2020년
# 0    1619  10232
# 1       7    200
# 2       6    130
# 3       3    617
# 4      26    456
# 5      24    175
# 6     130    104
# 7      21    930
# 8      41    233
# 9       0    486
# 10     49    192
# 11      0    271
# 12      0    288
# 13    179    438
# 14     66    240
# 15    282    198
# 16     29    356
# 17    209    415
# 18      0    508
# 19    122   1213
# 20     73    240
# 21    120    331
# 22    117    440
# 23     61    931
# 24      9    226
# 25     45    614

# %%
#2011년과 2020년 열 데이터 중 10~20번째 데이터 행 보기
CCTV_Seoul[['2011년', '2020년']][10:21]
# Out:
#     2011년  2020년
# 10     49    192
# 11      0    271
# 12      0    288
# 13    179    438
# 14     66    240
# 15    282    198
# 16     29    356
# 17    209    415
# 18      0    508
# 19    122   1213
# 20     73    240

# %%
#데이터의 통계정보 보기
CCTV_Seoul.describe()
# Out:
#                  총계     2011년 이전        2011년        2012년       2013년  \
# count     26.000000    26.000000    26.000000    26.000000   26.000000
# mean    5802.384615   453.923077   124.538462   171.384615  176.807692
# std    14243.300744  1153.586266   313.384522   424.613337  136.795035
# min     1356.000000     0.000000     0.000000     0.000000    0.000000
# 25%     2369.500000    14.500000     7.500000    36.000000   87.000000
# 50%     2649.500000   114.500000    43.000000    85.500000  140.000000
# 75%     3712.500000   369.500000   119.250000   134.250000  232.250000
# max    75431.000000  5901.000000  1619.000000  2228.000000  582.000000
#
#              2014년        2015년        2016년         2017년        2018년  \
# count    26.000000    26.000000    26.000000     26.000000    26.000000
# mean    336.000000   518.615385   638.461538    776.923077   745.153846
# std     832.063988  1283.423424  1582.773167   1919.477344  1835.587224
# ...

# %%
#데이터의 타입, 아이템 수, 누락데이터 등 보기
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     int64
#  2   2011년 이전  26 non-null     int64
#  3   2011년     26 non-null     int64
#  4   2012년     26 non-null     int64
#  5   2013년     26 non-null     int64
#  6   2014년     26 non-null     int64
#  7   2015년     26 non-null     int64
#  8   2016년     26 non-null     int64
#  9   2017년     26 non-null     int64
#  10  2018년     26 non-null     int64
#  11  2019년     26 non-null     int64
#  12  2020년     26 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# # 3. CCTV 현황 데이터 정리하기

# %%
#CCTV_Seoul 데이터의 0번째 열이름을 '구분' -> '구별'로 변경 (columns={'구분' : '구별'})
CCTV_Seoul.rename(columns = {'구분':'구별'}, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년 이전  2011년  2012년  2013년  2014년  2015년  2016년  2017년  \
# 0    계  75431      5901   1619   2228      0   4368   6742   8300  10100
# 1  종로구   1729       216      7     10    582    210    150      1    259
# 2   중구   2001        16      6    199     90    125    218    333    462
# 3  용산구   2383        31      3     71    234    125    221    298    351
# 4  성동구   3515       487     26    122    207    112    335    309    790
#
#    2018년  2019년  2020년
# 0   9687  11657  10232
# 1     85      9    200
# 2    228    194    130
# 3    125    307    617
# 4    409    262    456

# %%
#다른 데이터들과 년도를 동일하게 맞추기 위해 '2011년 이전과 2020년' 열 삭제 (columns=['2011년 이전'])
#CCTV_Seoul.drop(columns = ['2011년 이전'], axis = 1, inplace = True)
#CCTV_Seoul.drop(columns = ['2020년'], axis = 1, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년  2012년  2013년  2014년  2015년  2016년  2017년  2018년  2019년
# 0    계  75431   1619   2228      0   4368   6742   8300  10100   9687  11657
# 1  종로구   1729      7     10    582    210    150      1    259     85      9
# 2   중구   2001      6    199     90    125    218    333    462    228    194
# 3  용산구   2383      3     71    234    125    221    298    351    125    307
# 4  성동구   3515     26    122    207    112    335    309    790    409    262

# %%
#'2017년 이전' 열 추가  2017이전 = 총계-(2017년+2018년+2019년)
CCTV_Seoul['2017년 이전'] = CCTV_Seoul['총계'] - (CCTV_Seoul['2017년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2019년'])
CCTV_Seoul.head()
# Out:
#     구별     총계  2011년  2012년  2013년  2014년  2015년  2016년  2017년  2018년  2019년  \
# 0    계  75431   1619   2228      0   4368   6742   8300  10100   9687  11657
# 1  종로구   1729      7     10    582    210    150      1    259     85      9
# 2   중구   2001      6    199     90    125    218    333    462    228    194
# 3  용산구   2383      3     71    234    125    221    298    351    125    307
# 4  성동구   3515     26    122    207    112    335    309    790    409    262
#
#    2017년 이전
# 0     43987
# 1      1376
# 2      1117
# 3      1600
# 4      2054

# %%
#불필요한 년도의 열('2011년 이전', '2011년', '2012년', '2013년', '2014년','2015년','2016년') 삭제
#CCTV_Seoul.drop(columns=['2011년', '2012년', '2013년', '2014년','2015년','2016년'], axis=1, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별     총계  2017년  2018년  2019년  2017년 이전
# 0    계  75431  10100   9687  11657     43987
# 1  종로구   1729    259     85      9      1376
# 2   중구   2001    462    228    194      1117
# 3  용산구   2383    351    125    307      1600
# 4  성동구   3515    790    409    262      2054

# %%
#불필요한 행(index=0) 삭제
#CCTV_Seoul.drop(index = 0, axis = 0, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 1  종로구  1729    259     85      9      1376
# 2   중구  2001    462    228    194      1117
# 3  용산구  2383    351    125    307      1600
# 4  성동구  3515    790    409    262      2054
# 5  광진구  2556    675    465    712       704

# %%
 #기존의 인덱스는 버리고 새로 설정
CCTV_Seoul.reset_index(drop = True, inplace = True)
CCTV_Seoul.head()
# Out:
#     구별    총계  2017년  2018년  2019년  2017년 이전
# 0  종로구  1729    259     85      9      1376
# 1   중구  2001    462    228    194      1117
# 2  용산구  2383    351    125    307      1600
# 3  성동구  3515    790    409    262      2054
# 4  광진구  2556    675    465    712       704

# %% [markdown]
# # 4. CCTV 현황데이터 자세히 보기

# %% [markdown]
# ### 4-1. CCTV의 전체 개수가 가장 적은/가장 많은 상위 5개 구는 어디일까?

# %%
#데이터 '총계'열을 기준으로 오름차순 정렬하기 (by='총계', ascending = True)

CCTV_Seoul.sort_values(by = '총계', ascending = True).head()
# Out:
#      구별    총계  2017년  2018년  2019년  2017년 이전
# 9   도봉구  1356    134    223    214       785
# 0   종로구  1729    259     85      9      1376
# 1    중구  2001    462    228    194      1117
# 19  동작구  2262    278    255    242      1487
# 10  노원구  2282    256    201    240      1585

# %%
#데이터 '총계'열을 기준으로 내림차순 정렬하기 (by='총계', ascending = False)

CCTV_Seoul.sort_values(by = '총계', ascending = False).head()
# Out:
#       구별    총계  2017년  2018년  2019년  2017년 이전
# 22   강남구  6645   1004    744    796      4101
# 20   관악구  4909    684    674    596      2955
# 16   구로구  4075    540    488    434      2613
# 18  영등포구  3773    311    658     65      2739
# 7    성북구  3754    461    860    716      1717

# %% [markdown]
# ### 4-2. 최근 3년간 CCTV 증가율을 계산하여 '최근증가율' 을 알아보자.

# %%
#최근 3년간 CCTV 수를 더하고 2017년 이전 CCTV수로 나눠서 최근 3년간 CCTV 증가율 계산

CCTV_Seoul['최근증가율']=(CCTV_Seoul['2017년'] + CCTV_Seoul['2018년'] + CCTV_Seoul['2019년']) / CCTV_Seoul['2017년 이전']*100
CCTV_Seoul.head()
# Out:
#      구별    총계  2017년  2018년  2019년  2017년 이전      최근증가율
# 9   도봉구  1356    134    223    214       785  72.738854
# 0   종로구  1729    259     85      9      1376  25.654070
# 1    중구  2001    462    228    194      1117  79.140555
# 19  동작구  2262    278    255    242      1487  52.118359
# 10  노원구  2282    256    201    240      1585  43.974763

# %% [markdown]
# ### 4-3. '최근증가율' 이 가장 높은 상위 5개구는 어디일까?

# %%
#'최근증가율'로 내림차순 정렬
CCTV_Seoul.sort_values(by = '최근증가율', ascending = False).head()
# Out:
#      구별    총계  2017년  2018년  2019년  2017년 이전       최근증가율
# 4   광진구  2556    675    465    712       704  263.068182
# 23  송파구  2743    241    542   1068       892  207.511211
# 11  은평구  3660    403    635   1057      1565  133.865815
# 8   강북구  2462     34    385    976      1067  130.740394
# 7   성북구  3754    461    860    716      1717  118.637158

# %% [markdown]
# # 5. 서울시 자치구별 CCTV 현황 시각화

# %%
#한글폰트 깨짐 방지 코드

import matplotlib.pyplot as plt

import platform
path = "c:/windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system... sorry~~~')

# %%
# '최근 증가율' 중 상위 10개를 bar 차트로 생성하기
RateTop10 = CCTV_Seoul.sort_values(by = '최근증가율', ascending = False).head(10)
RateTop10   #결과 확인
plt.bar(RateTop10['구별'], RateTop10['최근증가율'])
plt.show()

# %%
# (2) 총계를 기준으로 상위 5개 구의 2017년~2019년 CCTV 수를  라인차트 그리기
Top10 = CCTV_Seoul.sort_values(by = '총계', ascending = False).head()
plt.plot(Top10['구별'], Top10['2017년'])
plt.plot(Top10['구별'], Top10['2018년'])
plt.plot(Top10['구별'], Top10['2019년'])

plt.show()

# %%
# (3) 마크 추가하기
plt.plot(Top10['구별'], Top10['2017년'], label = '2017', marker = 'o')
plt.plot(Top10['구별'], Top10['2018년'], label = '2018', marker = 'v')
plt.plot(Top10['구별'], Top10['2019년'], label = '2019', marker = 'x')
plt.legend()
plt.show()

# %%
# (4) 각 년도 레이블 넣기
plt.plot(Top10['구별'], Top10['2017년'], label = '2017')
plt.plot(Top10['구별'], Top10['2018년'], label = '2018')
plt.plot(Top10['구별'], Top10['2019년'], label = '2019')
plt.legend()
plt.show()

# %%
# (5) 차트 제목, X축, Y축 레이블 넣기
plt.plot(Top10['구별'], Top10['2017년'], label = '2017', marker = 'o')
plt.plot(Top10['구별'], Top10['2018년'], label = '2018', marker = 'v')
plt.plot(Top10['구별'], Top10['2019년'], label = '2019', marker = 'x')
plt.title('자치구별 CCTV 현황')
plt.xlabel('자치구 명')
plt.ylabel('CCTV 수')
plt.legend()
plt.show()

# %%
# (6) grid  추가하기
plt.plot(Top10['구별'], Top10['2017년'], label = '2017', marker = 'o')
plt.plot(Top10['구별'], Top10['2018년'], label = '2018', marker = 'v')
plt.plot(Top10['구별'], Top10['2019년'], label = '2019', marker = 'x')
plt.title('자치구별 CCTV 현황')
plt.xlabel('자치구 명')
plt.ylabel('CCTV 수')
plt.grid()
plt.legend()
plt.show()
